# %%
# %pip install nest_asyncio flask flask_restful
# Out:
# Requirement already satisfied: nest_asyncio in c:\users\kekohueko\pydev\e2\lib\site-packages (1.5.8)
# Requirement already satisfied: flask in c:\users\kekohueko\pydev\e2\lib\site-packages (3.1.2)
# Collecting flask_restful
#   Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\kekohueko\pydev\e2\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\kekohueko\pydev\e2\lib\site-packages (from flask) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\kekohueko\pydev\e2\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\kekohueko\pydev\e2\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\kekohueko\pydev\e2\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\kekohueko\pydev\e2\lib\site-packages (from flask) (3.1.3)
# Collecting aniso8601>=0.82 (from flask_restful)
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: six>=1.3.0 in c:\users\kekohueko\pydev\e2\lib\site-packages (from flask_restful) (1.16.0)
# Requirement already satisfied: pytz in c:\users\kekohueko\pydev\e2\lib\site-packages (from flask_restful) (2021.3)
# Requirement already satisfied: colorama in c:\users\kekohueko\pydev\e2\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl (26 kB)
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
# Installing collected packages: aniso8601, flask_restful
#
#    ---------------------------------------- 0/2 [aniso8601]
#    ---------------------------------------- 0/2 [aniso8601]
#    ---------------------------------------- 0/2 [aniso8601]
#    ---------------------------------------- 0/2 [aniso8601]
#    -------------------- ------------------- 1/2 [flask_restful]
#    -------------------- ------------------- 1/2 [flask_restful]
#    ---------------------------------------- 2/2 [flask_restful]
#
# Successfully installed aniso8601-10.0.1 flask_restful-0.3.10
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kekohueko\pydev\e2\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kekohueko\pydev\e2\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kekohueko\pydev\e2\lib\site-packages)

# %%
import nest_asyncio
from flask import Flask, request
from flask_restful import Api, Resource
from threading import Thread

# %%
books = [
    {"isbn": "1234567890", "title": "The Great Gatsby", "author": "F. Scott Fitzgerald", "price": 10.99},
    {"isbn": "0987654321", "title": "1984", "author": "George Orwell", "price": 8.99}
]

# %%
app = Flask(__name__)
api = Api(app)

# %%
class Book(Resource):
    def get(self, isbn=None):
        if isbn:
            for book in books:
                if book['isbn'] == isbn:
                    return book, 200
            return {"message": "Book not found"}, 404
        return books, 200
    
    def post(self):
        new_book = request.json
        books.append(new_book)
        return new_book, 201
    
    def put(self, isbn):
        for book in books:
            if book['isbn'] == isbn:
                book.update(request.json)
                return book, 200
        return {"message": "Book not found"}, 404
    
    def delete(self, isbn):
        global books
        books = [book for book in books if book['isbn'] != isbn]
        return {"message": "Book deleted"}, 200

# %%
api.add_resource(Book, '/books', '/books/<string:isbn>')

# %%
nest_asyncio.apply()
def run_app():
    app.run(port=5000, debug=False)

thread = Thread(target=run_app)
thread.start()

print("API is running! Test it at http://127.0.0.1:5000/books")
# Out:
# API is running! Test it at http://127.0.0.1:5000/books
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [11/Oct/2025 18:46:21] "GET /books HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Oct/2025 18:46:21] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Oct/2025 18:47:14] "GET /books HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Oct/2025 18:47:41] "GET /books/1234567890 HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Oct/2025 18:47:46] "GET /books/12345678 HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Oct/2025 18:48:21] "GET /books/1234567890 HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Oct/2025 18:49:21] "POST /books HTTP/1.1" 415 -
# 127.0.0.1 - - [11/Oct/2025 18:53:09] "PUT /books/1234567890 HTTP/1.1" 415 -
# 127.0.0.1 - - [11/Oct/2025 18:53:48] "DELETE /books/1234567890 HTTP/1.1" 200 -

# %%
books
# Out:
# [{'isbn': '0987654321',
#   'title': '1984',
#   'author': 'George Orwell',
#   'price': 8.99}]
# [2025-10-11 18:55:32,651] ERROR in app: Exception on /books/1234567890 [POST]
# Traceback (most recent call last):
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask_restful\__init__.py", line 489, in wrapper
#     resp = resource(*args, **kwargs)
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask_restful\__init__.py", line 604, in dispatch_request
#     resp = meth(*args, **kwargs)
# TypeError: Book.post() got an unexpected keyword argument 'isbn'
# 127.0.0.1 - - [11/Oct/2025 18:55:32] "POST /books/1234567890 HTTP/1.1" 500 -
# [2025-10-11 18:56:08,763] ERROR in app: Exception on /books/1234567890 [POST]
# Traceback (most recent call last):
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask_restful\__init__.py", line 489, in wrapper
#     resp = resource(*args, **kwargs)
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#   File "c:\Users\kekohueko\PyDev\E2\lib\site-packages\flask_restful\__init__.py", line 604, in dispatch_request
#     resp = meth(*args, **kwargs)
# TypeError: Book.post() got an unexpected keyword argument 'isbn'
# 127.0.0.1 - - [11/Oct/2025 18:56:08] "POST /books/1234567890 HTTP/1.1" 500 -

# %%
books
# Out:
# [{'isbn': '0987654321',
#   'title': '1984',
#   'author': 'George Orwell',
#   'price': 8.99}]
# 127.0.0.1 - - [11/Oct/2025 18:56:44] "GET /books/1234567890 HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Oct/2025 18:56:50] "GET /books HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Oct/2025 18:57:18] "GET /books HTTP/1.1" 200 -

# %%
quit
# Out:
# 127.0.0.1 - - [11/Oct/2025 18:58:16] "GET /books HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Oct/2025 18:58:17] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Oct/2025 18:59:12] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Oct/2025 18:59:13] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Oct/2025 18:59:13] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Oct/2025 18:59:22] "GET /books HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Oct/2025 18:59:22] "GET /books HTTP/1.1" 200 -
