# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - Learn about Data Science languages
# - Get to know common Data Science libraries for data science
# - Learn about tools used for DS
# - Get the basics of using Jupyter notebooks Markdown cells
# - Familiarize with basic arithmetic operations in jupyter notebooks in Code Cells

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# * Python
# * R
# * Scala

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# * Numpy
# * Pandas
# * Matplotlib

# %% [markdown]
# | Data Science Tools |
# |---|
# | R Studio |
# |Jupyter Notebooks|
# |IBM Watson Studio|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This a simple arithmetic expression to mutiply then add integers

(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
minutes_per_hour=60
minutes=200
total_hours=minutes/minutes_per_hour
total_hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Jhon Diego Ledesma
